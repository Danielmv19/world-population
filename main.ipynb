# %%
import pandas as pd 
import numpy as np
import pprint as pp

# %%
data = pd.read_csv('world_population_data.csv')

# %%
df = pd.DataFrame(data)

# %%
df.head(3)
# Out:
#    rank cca3        country      continent  2023 population  2022 population  \
# 0     1  IND          India           Asia       1428627663       1417173173
# 1     2  CHN          China           Asia       1425671352       1425887337
# 2     3  USA  United States  North America        339996563        338289857
#
#    2020 population  2015 population  2010 population  2000 population  \
# 0       1396387127       1322866505       1240613620       1059633675
# 1       1424929781       1393715448       1348191368       1264099069
# 2        335942003        324607776        311182845        282398554
#
#    1990 population  1980 population  1970 population  area (km²)  \
# 0        870452165        696828385        557501301   3287590.0
# 1       1153704252        982372466        822534450   9706961.0
# 2        248083732        223140018        200328340   9372610.0
#
#    density (km²) growth rate world percentage
# 0            481       0.81%           17.85%
# ...

# %%
df[['country', '2023 population']].head(3)
# Out:
#          country  2023 population
# 0          India       1428627663
# 1          China       1425671352
# 2  United States        339996563

# %%
df.country.head(3)
# Out:
# 0            India
# 1            China
# 2    United States
# Name: country, dtype: object

# %%
pd.isna(df).head(3)
# Out:
#     rank   cca3  country  continent  2023 population  2022 population  \
# 0  False  False    False      False            False            False
# 1  False  False    False      False            False            False
# 2  False  False    False      False            False            False
#
#    2020 population  2015 population  2010 population  2000 population  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
#
#    1990 population  1980 population  1970 population  area (km²)  \
# 0            False            False            False       False
# 1            False            False            False       False
# 2            False            False            False       False
#
#    density (km²)  growth rate  world percentage
# 0          False        False             False
# ...

# %%
df.tail(3)
# Out:
#      rank cca3       country continent  2023 population  2022 population  \
# 231   232  NIU          Niue   Oceania             1935             1934
# 232   233  TKL       Tokelau   Oceania             1893             1871
# 233   234  VAT  Vatican City    Europe              518              510
#
#      2020 population  2015 population  2010 population  2000 population  \
# 231             1942             1847             1812             2074
# 232             1827             1454             1367             1666
# 233              520              564              596              651
#
#      1990 population  1980 population  1970 population  area (km²)  \
# 231             2533             3637             5185      261.00
# 232             1669             1647             1714       12.00
# 233              700              733              752        0.44
#
#      density (km²) growth rate world percentage
# 231              7       0.05%            0.00%
# ...

# %%
df.columns
# Out:
# Index(['rank', 'cca3', 'country', 'continent', '2023 population',
#        '2022 population', '2020 population', '2015 population',
#        '2010 population', '2000 population', '1990 population',
#        '1980 population', '1970 population', 'area (km²)', 'density (km²)',
#        'growth rate', 'world percentage'],
#       dtype='object')

# %%
df.iloc[0]
# Out:
# rank                         1
# cca3                       IND
# country                  India
# continent                 Asia
# 2023 population     1428627663
# 2022 population     1417173173
# 2020 population     1396387127
# 2015 population     1322866505
# 2010 population     1240613620
# 2000 population     1059633675
# 1990 population      870452165
# 1980 population      696828385
# 1970 population      557501301
# area (km²)           3287590.0
# density (km²)              481
# growth rate              0.81%
# world percentage        17.85%
# Name: 0, dtype: object

# %%
df['Asia?'] = df['continent'] == 'Asia'

# %%
df.head(7)
# Out:
#    rank cca3        country      continent  2023 population  2022 population  \
# 0     1  IND          India           Asia       1428627663       1417173173
# 1     2  CHN          China           Asia       1425671352       1425887337
# 2     3  USA  United States  North America        339996563        338289857
# 3     4  IDN      Indonesia           Asia        277534122        275501339
# 4     5  PAK       Pakistan           Asia        240485658        235824862
# 5     6  NGA        Nigeria         Africa        223804632        218541212
# 6     7  BRA         Brazil  South America        216422446        215313498
#
#    2020 population  2015 population  2010 population  2000 population  \
# 0       1396387127       1322866505       1240613620       1059633675
# 1       1424929781       1393715448       1348191368       1264099069
# 2        335942003        324607776        311182845        282398554
# 3        271857970        259091970        244016173        214072421
# ...

# %%
del df['Asia?']

# %%
df
# Out:
#      rank cca3           country      continent  2023 population  \
# 0       1  IND             India           Asia       1428627663
# 1       2  CHN             China           Asia       1425671352
# 2       3  USA     United States  North America        339996563
# 3       4  IDN         Indonesia           Asia        277534122
# 4       5  PAK          Pakistan           Asia        240485658
# ..    ...  ...               ...            ...              ...
# 229   230  MSR        Montserrat  North America             4386
# 230   231  FLK  Falkland Islands  South America             3791
# 231   232  NIU              Niue        Oceania             1935
# 232   233  TKL           Tokelau        Oceania             1893
# 233   234  VAT      Vatican City         Europe              518
#
#      2022 population  2020 population  2015 population  2010 population  \
# 0         1417173173       1396387127       1322866505       1240613620
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=234, step=1)

# %%
df.iloc[0]
# Out:
# rank                         1
# cca3                       IND
# country                  India
# continent                 Asia
# 2023 population     1428627663
# 2022 population     1417173173
# 2020 population     1396387127
# 2015 population     1322866505
# 2010 population     1240613620
# 2000 population     1059633675
# 1990 population      870452165
# 1980 population      696828385
# 1970 population      557501301
# area (km²)           3287590.0
# density (km²)              481
# growth rate              0.81%
# world percentage        17.85%
# Name: 0, dtype: object

# %%
df['country']
# Out:
# 0                 India
# 1                 China
# 2         United States
# 3             Indonesia
# 4              Pakistan
#              ...
# 229          Montserrat
# 230    Falkland Islands
# 231                Niue
# 232             Tokelau
# 233        Vatican City
# Name: country, Length: 234, dtype: object

# %%
paises_asia = df[df['continent'] == 'Asia']

# %%
paises_asia
# Out:
#      rank cca3               country continent  2023 population  \
# 0       1  IND                 India      Asia       1428627663
# 1       2  CHN                 China      Asia       1425671352
# 3       4  IDN             Indonesia      Asia        277534122
# 4       5  PAK              Pakistan      Asia        240485658
# 7       8  BGD            Bangladesh      Asia        172954319
# 11     12  JPN                 Japan      Asia        123294513
# 12     13  PHL           Philippines      Asia        117337368
# 15     16  VNM               Vietnam      Asia         98858950
# 16     17  IRN                  Iran      Asia         89172767
# 17     18  TUR                Turkey      Asia         85816199
# 19     20  THA              Thailand      Asia         71801279
# 26     27  MMR               Myanmar      Asia         54577997
# 28     29  KOR           South Korea      Asia         51784059
# 34     35  IRQ                  Iraq      Asia         45504560
# ...

# %%
paises_asia.shape
# Out:
# (50, 17)

# %%
paises_asia.loc[11]
# Out:
# rank                       12
# cca3                      JPN
# country                 Japan
# continent                Asia
# 2023 population     123294513
# 2022 population     123951692
# 2020 population     125244761
# 2015 population     127250933
# 2010 population     128105431
# 2000 population     126803861
# 1990 population     123686321
# 1980 population     117624196
# 1970 population     105416839
# area (km²)           377930.0
# density (km²)             338
# growth rate            -0.53%
# world percentage        1.54%
# Name: 11, dtype: object

# %%
paises_asia.loc[11, ['country']]
# Out:
# country    Japan
# Name: 11, dtype: object
